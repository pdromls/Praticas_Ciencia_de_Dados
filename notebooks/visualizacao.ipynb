# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as sts

ARQ = '../data/raw/trees.csv'

df = pd.read_csv(ARQ)

df.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
plt.hist(df.iloc[:,1], bins = 6)
# Out:
# (array([4., 2., 5., 7., 9., 4.]),
#  array([63., 67., 71., 75., 79., 83., 87.]),
#  <BarContainer object of 6 artists>)

# %%
# kde = linha de densidade
sns.histplot(df.iloc[:,1], kde = False, bins = 6).set(title='Árvores')
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
sns.kdeplot(df.iloc[:,1]).set(title='Árvores')
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
sns.histplot(df.iloc[:,1], kde = True, bins = 6).set(title='Árvores')
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
plt.scatter(x=df.Girth, y=df.Volume)
plt.title('Dispersão entre Circunferência e Volume')
plt.xlabel('Circunferência (Girth)')
plt.ylabel('Volume')
plt.show()

# %%
plt.plot(df.Girth, df.Volume)
plt.title('Dispersão entre Circunferência e Volume')
plt.xlabel('Circunferência (Girth)')
plt.ylabel('Volume')
plt.show()

# %%
# jitter espalha um pouco os pontos para melhor visualização quando estão no mesmo local
# fit_reg = linha de tendência
sns.regplot(x=df.Girth, y=df.Volume, data=df, fit_reg=False, x_jitter=0.3)
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>

# %%
sns.regplot(x=df.Girth, y=df.Height, data=df, fit_reg=False, x_jitter=0.3)
# Out:
# <Axes: xlabel='Girth', ylabel='Height'>

# %%
sns.regplot(x=df.Height, y=df.Volume, data=df, fit_reg=False, x_jitter=0.3)
# Out:
# <Axes: xlabel='Height', ylabel='Volume'>

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.regplot(x=df.Girth, y=df.Volume, data=df, fit_reg=False, x_jitter=0.3)
plt.subplot(2,2,2)
sns.regplot(x=df.Girth, y=df.Height, data=df, fit_reg=False, x_jitter=0.3)
plt.subplot(2,2,3)
sns.regplot(x=df.Height, y=df.Volume, data=df, fit_reg=False, x_jitter=0.3)
# plt.subplots_adjust(hspace=0.4, wspace=0.3)  # ajusta espaçamento vertical/horizontal
plt.tight_layout()  # melhora ajuste final
plt.show()

# %%
sns.boxplot(data=df.Volume, orient='v')
plt.title('Boxplot do Volume das Árvores')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as sts

ARQ = '../data/raw/co2.csv'

df2 = pd.read_csv(ARQ)

df2.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
unicos = list(set(df2.Treatment))
unicos
# Out:
# ['chilled', 'nonchilled']

# %%
tipos = list(set(df2.Type))
tipos
# Out:
# ['Quebec', 'Mississippi']

# %%
# Percorre cada tipo de tratamento e plota um gráfico de dispersão
for tratamento in unicos:
    dados_tratamento = df2[df2.Treatment == tratamento]
    plt.scatter(dados_tratamento.conc, dados_tratamento.uptake, label=tratamento)
plt.legend(loc='lower right')

# %%
sns.scatterplot(x=df2.conc, y=df2.uptake, hue=df2.Type)
plt.show()

# %%
q = df2.loc[df2.Type == 'Quebec']
m = df2.loc[df2.Type == 'Mississippi'] 

plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
sns.scatterplot(x=q.conc, y=q.uptake)
plt.title('Quebec')
plt.subplot(1,2,2)
sns.scatterplot(x=m.conc, y=m.uptake)
plt.title('Mississippi')
plt.tight_layout()
plt.show()

# %%
ch = df2.loc[(df2.Treatment == 'chilled')]
nch = df2.loc[(df2.Treatment == 'nonchilled')]

plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
sns.scatterplot(x=ch.conc, y=ch.uptake)
plt.title('Chilled')
plt.subplot(1,2,2)
sns.scatterplot(x=nch.conc, y=nch.uptake)
plt.title('Nonchilled')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as sts

ARQ = '../data/raw/insect.csv'

df3 = pd.read_csv(ARQ)

df3.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
df3.shape
# Out:
# (72, 2)

# %%
agrupado = df3.groupby('spray')['count'].sum()
agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrupado.plot.bar()
# Out:
# <Axes: xlabel='spray'>

# %%
agrupado.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as sts

ARQ = '../data/raw/chicken.csv'

df4 = pd.read_csv(ARQ)

df4.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
agrupado = df4.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.subplot(3,2,1)
sns.histplot(df4.loc[df4['feed'] == 'casein'].weight, kde=True)
plt.title('Feed: Casein')
plt.subplot(3,2,2)
sns.histplot(df4.loc[df4['feed'] == 'horsebean'].weight, kde=True)
plt.title('Feed: Horsebean')
plt.subplot(3,2,3)
sns.histplot(df4.loc[df4['feed'] == 'linseed'].weight, kde=True)
plt.title('Feed: Linseed')
plt.subplot(3,2,4)
sns.histplot(df4.loc[df4['feed'] == 'meatmeal'].weight, kde=True)
plt.title('Feed: Meatmeal')
plt.subplot(3,2,5)
sns.histplot(df4.loc[df4['feed'] == 'soybean'].weight, kde=True)
plt.title('Feed: Soybean')
plt.subplot(3,2,6)
sns.histplot(df4.loc[df4['feed'] == 'sunflower'].weight, kde=True)
plt.title('Feed: Sunflower')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as sts

ARQ = '../data/raw/esoph.csv'

df5 = pd.read_csv(ARQ)

df5.head()
# Out:
#    agegp      alcgp     tobgp  ncases  ncontrols
# 0  25-34  0-39g/day  0-9g/day       0         40
# 1  25-34  0-39g/day     10-19       0         10
# 2  25-34  0-39g/day     20-29       0          6
# 3  25-34  0-39g/day       30+       0          5
# 4  25-34      40-79  0-9g/day       0         27

# %%
sns.catplot(x='alcgp', y='ncontrols', data=df5, jitter=False)

# %%
sns.catplot(x='alcgp', y='ncontrols', data=df5, col = 'tobgp')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as sts

ARQ = '../data/raw/dados.csv'

df6 = pd.read_csv(ARQ,
                sep = ';',
)

pd.options.display.float_format = '{:.2f}'.format

df6.head()
# Out:
#    CODIGO               MUNICIPIO      PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO 12240.76    1088666.10
# 1     113            SANTO ANGELO 16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS 12037.61     466122.80
# 3      13         CACAPAVA DO SUL 13674.54     485535.86
# 4     120             SAO GABRIEL 19912.38     533719.86

# %%
df6.shape
# Out:
# (187, 4)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CODIGO        187 non-null    int64
#  1   MUNICIPIO     187 non-null    object
#  2   PIB           187 non-null    float64
#  3   VALOREMPENHO  187 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
df6.describe()
# Out:
#        CODIGO       PIB  VALOREMPENHO
# count  187.00    187.00        187.00
# mean   247.16  19808.74     129984.42
# std    138.75  16984.22     161549.14
# min      1.00   8236.63        172.13
# 25%    141.00  13621.45      52517.18
# 50%    242.00  17206.19      84228.16
# 75%    372.50  21429.17     153896.15
# max    496.00 223848.22    1442759.82

# %%
sns.regplot(x=df6.PIB, y=df6.VALOREMPENHO, fit_reg=False, x_jitter=True)
plt.title('Dispersão entre PIB e Valor Empenhado')
plt.xlabel('PIB')
plt.ylabel('Valor Empenhado')
plt.show()

# %%
sns.boxplot(data=df6.PIB, orient='v')
plt.title('Boxplot do PIB')
plt.ylabel('PIB')
plt.show()

# %%
sns.boxplot(data=df6.VALOREMPENHO, orient='v')
plt.title('Boxplot do Valor Empenhado') 
plt.ylabel('Valor Empenhado')
plt.show()

# %%
pib_por_municipio = df6.groupby('MUNICIPIO')['PIB'].sum()
pib_por_municipio = pib_por_municipio.sort_values(ascending=False)
pib_por_municipio.head()
# Out:
# MUNICIPIO
# TRIUNFO                   223848.22
# MUITOS CAPOES              72353.72
# GARRUCHOS                  68672.25
# MATO LEITAO                44384.87
# SANTA VITORIA DO PALMAR    44384.87
# Name: PIB, dtype: float64

# %%
grafico = sns.barplot(x=pib_por_municipio.index[:10], y=pib_por_municipio.values[:10])

for container in grafico.containers:
    grafico.bar_label(container, fmt='{:,.0f}', padding=0.8, size=6)

plt.title('Top 10 Municípios por PIB')
plt.xlabel('Municípios')
plt.xticks(rotation=45, ha='right')
plt.ylabel('PIB')
plt.tight_layout()
plt.show()

# %%
valorempenho_por_municipio = df6.groupby('MUNICIPIO')['VALOREMPENHO'].sum()
valorempenho_por_municipio = valorempenho_por_municipio.sort_values(ascending=False)
valorempenho_por_municipio.head()
# Out:
# MUNICIPIO
# TRIUNFO                 1442759.82
# SANTANA DO LIVRAMENTO   1088666.10
# SANTO ANGELO             800669.92
# SAO GABRIEL              533719.86
# CACAPAVA DO SUL          485535.86
# Name: VALOREMPENHO, dtype: float64

# %%
grafico = sns.barplot(x=valorempenho_por_municipio.index[:10], y=valorempenho_por_municipio.values[:10])

for container in grafico.containers:
    grafico.bar_label(container, fmt='{:,.0f}', padding=0.8, size=6)

plt.title('Top 10 Municípios por Valor Empenhado')
plt.xlabel('Municípios')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Valor Empenhado')
plt.tight_layout()
plt.show()
